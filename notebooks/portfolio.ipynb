# %%
# %load_ext autoreload
# %autoreload 2

# %%
import invest_toolkit as it

# %%
"""
Распредеоение активов для порфтеля
"""
it.log.init('РАСПРЕДЕЛЕНИЕ АКТИВОВ В ПОРТФЕЛЕ')
it.portfolio_report(
        report_path_sber = r'../.reports\400LSUS_10062026.html' ,
        report_path_vtb = r'../.reports\vtb20260622.xlsx' ,
        allocation_path = r'../support_files/index_fund.xlsx',
        deposit = 51000,
        grouping_tickers=['LQDT', 'SBMM'],
        allow_sell_tickers=['LQDT', 'SBMM'],
        sell=True,
        report_save_path = r'../.output'
)
# Out:
# c:\Users\ilya\Documents\MyDocs\02_github\invest_toolkit\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Отчет сгенерирован в ../.output
# лог файл: c:\Users\ilya\Documents\MyDocs\02_github\invest_toolkit\notebooks\.log\app.log
