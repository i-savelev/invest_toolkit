# %% [markdown]
# # Анализ компаний

# %%
# %load_ext autoreload
# %autoreload 2

# %%
"""
Список показателей для компаний (не банки)
"""
METRIC_LIST_1 = [
    'Выручка, млрд руб',
    'Чистая прибыль, млрд руб',
    'Чистый долг, млрд руб',
    'Долг/EBITDA',
    'Див.выплата, млрд руб',
    'Див доход, ао, %',
]

METRIC_LIST_2 = [
    'Чистая прибыль, млрд руб', 
    'Чистый операц доход, млрд руб',
    'Чист. проц. доходы, млрд руб', 
    'Чист. комисс. доход, млрд руб', 
    'Доходы по цб, млрд руб',
]

METRIC_LIST_3 = [
    'Чистая прибыль, млрд руб', 
    'Чист. проц. доходы, млрд руб',
    'Чист. комисс. доход, млрд руб',
    'Выручка, млрд руб',
]

METRIC_LIST_4 = [
    'Выручка, млрд руб',
    'Чистая прибыль, млрд руб',
]

# %%
"""
Импорты
"""
import invest_toolkit as it
import pandas as pd

# %%
"""
Чтение датафрейма, который получен с помощью 
> it.all_stock_info()
"""
df = pd.read_csv(r'../.output/all_stock_info.csv')

display(df.head())

# %%
"""
Вывод одного графика
"""
it.plot_one_chart(
    ticker='GAZP',
    title='Чистая прибыль, млрд руб',
    df = df
)

# %%
"""
Вывод множества графиков
"""
it.plot_multiple_chart(
    df = df,
    ticker='T',
    metric_list=METRIC_LIST_2,
)

# %%
"""
Вывод множества графиков
"""
it.plot_multiple_chart(
    df = df,
    ticker='',
    metric_list=METRIC_LIST_1,
)
