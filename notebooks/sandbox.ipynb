# %%
# %load_ext autoreload
# %autoreload 2

# %%
import invest_toolkit as it
import pandas as pd

# %%
ir_df= it.ir_rating(r'../support_files/ir_rating.xlsx')

# %%
df = it.merge_csv_files(r'../support_files/scrapper_reports')

# %%
ir_list = set(ir_df['ticker'].tolist())
sl_list = set(df['ticker'].tolist())
ir_list - sl_list
