# %%
# %load_ext autoreload
# %autoreload 2

# %%
import invest_toolkit as it
import pandas as pd

# %%
index = pd.read_excel(r'../support_files/index_fund.xlsx', sheet_name=None)

# %%
index['stock']

# %%
df_all = pd.read_csv(r'../.output/all_stock_info.csv')
df_cap = df_all[df_all['indicator']=='cap']
df_ff = df_all[df_all['indicator']=='free_float']
df_cap['value'] = df_cap['value'].astype(float)/1000000000
df_ff

# %%
result = pd.merge(index['stock'], df_cap, on='ticker', how='left')
result = pd.merge(result, df_ff, on='ticker', how='left')

# %%
df_rating = pd.read_csv(r'../.output\datalens_rating.csv')
df_rating.head()

# %%
result = pd.merge(result, df_rating, on='ticker', how='left')
result.head()
result.to_excel(r'../.output/update_for_index.xlsx')
